# %% [markdown]
# # Video Game Sales Data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./vgsales.csv')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# df['Year'] = df['Year'].astype(int)
# df.isnull().values.any()
# df['Year'] = df['Year'].apply(lambda val: 0 if val is None else int(val))

# %% [markdown]
# # 1. Which company is the most common video game publisher?

# %%
df['Publisher'].groupby(df['Publisher']).count().sort_values(ascending=False).head(5)
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
# Name: Publisher, dtype: int64

# %%
df[df.Publisher == 'Electronic Arts'].head(5)
# Out:
#     Rank                          Name Platform    Year       Genre  \
# 77    78                       FIFA 16      PS4  2015.0      Sports
# 82    83                FIFA Soccer 13      PS3  2012.0      Action
# 83    84                    The Sims 3       PC  2009.0  Simulation
# 92    93  Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 99   100                 Battlefield 3     X360  2011.0     Shooter
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 77  Electronic Arts      1.11      6.06      0.06         1.26          8.49
# 82  Electronic Arts      1.06      5.05      0.13         2.01          8.24
# 83  Electronic Arts      0.98      6.42      0.00         0.71          8.11
# 92  Electronic Arts      2.93      3.29      0.22         1.23          7.67
# 99  Electronic Arts      4.46      2.13      0.06         0.69          7.34

# %% [markdown]
# # 2. What's the most common platform?

# %%
pd.DataFrame(df['Platform'].groupby(df['Platform']).count().sort_values(ascending=False).head(5))
# Out:
#           Platform
# Platform
# DS            2163
# PS2           2161
# PS3           1329
# Wii           1325
# X360          1265

# %% [markdown]
# # 3. What's the most common genre?

# %%
pd.DataFrame(df['Genre'].groupby(df['Genre']).count().sort_values(ascending=False).head(5))
# Out:
#               Genre
# Genre
# Action         3316
# Sports         2346
# Misc           1739
# Role-Playing   1488
# Shooter        1310

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
# Rank            16598 non-null int64
# Name            16598 non-null object
# Platform        16598 non-null object
# Year            16327 non-null float64
# Genre           16598 non-null object
# Publisher       16540 non-null object
# NA_Sales        16598 non-null float64
# EU_Sales        16598 non-null float64
# JP_Sales        16598 non-null float64
# Other_Sales     16598 non-null float64
# Global_Sales    16598 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# # 4. What are the top 20 highest grossing games?

# %%
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# df[['Name', 'Global_Sales']].head(5)
df.sort_values('Global_Sales', ascending=False).head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # 5. For North American video game sales, what's the median?

# %%
df['NA_Sales'].median()
# Out:
# 0.08

# %%
# df[df.NA_Sales == 0.08]

# %% [markdown]
# # 6. For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
(df['NA_Sales'].max() - df['NA_Sales'].mean()) / df['NA_Sales'].std()
# Out:
# 50.47898767479108

# %% [markdown]
# # 7. The Nintendo Wii seems to have outdone itself with games. How does it's average number of sales compare with all of the other platforms?

# %%
df['Global_Sales'].groupby(df.Platform).mean().sort_values(ascending=False)
# Out:
# Platform
# GB      2.606633
# NES     2.561939
# GEN     1.050370
# SNES    0.837029
# PS4     0.827679
# X360    0.774672
# 2600    0.729925
# PS3     0.720722
# Wii     0.699404
# N64     0.686144
# XOne    0.662254
# PS      0.610920
# PS2     0.581046
# WiiU    0.572448
# 3DS     0.486169
# GBA     0.387470
# DS      0.380254
# GC      0.358561
# XB      0.313422
# SCD     0.311667
# DC      0.307115
# PC      0.269604
# PSP     0.244254
# WS      0.236667
# SAT     0.194162
# PSV     0.149952
# NG      0.120000
# TG16    0.080000
# GG      0.040000
# 3DO     0.033333
# PCFX    0.030000
# Name: Global_Sales, dtype: float64
